# %%
import os
from dotenv import load_dotenv

load_dotenv()
from langchain_openai import AzureChatOpenAI
llm = AzureChatOpenAI(azure_endpoint=os.environ["AZURE_OPENAI_ENDPOINT"],
    azure_deployment=os.environ["AZURE_OPENAI_DEPLOYMENT_NAME"],
    api_version=os.environ["AZURE_OPENAI_API_VERSION"])

# %%
userquery= "I want to build an agent that retrieves latest updates from my email and slack, summarizes the highlights and updates my calenders for events. What are the different subagents needed?"

# %%
response = llm.invoke(userquery)

# %%
from pprint import pprint 

pprint(response.content)
# Out:
# ('Building an agent that can retrieve updates from your email and Slack, '
#  'summarize highlights, and update your calendar involves several components '
#  'or subagents. Below are the key subagents you might consider implementing:\n'
#  '\n'
#  '1. **Email Retrieval Agent**:\n'
#  '   - **Function**: This subagent connects to your email account (using '
#  'protocols like IMAP/SMTP) to fetch unread emails, or emails from specific '
#  'folders.\n'
#  '   - **Features**: \n'
#  '     - Filter emails by keywords, sender, or dates.\n'
#  '     - Prioritize emails based on importance (e.g., from colleagues or '
#  'project tags).\n'
#  '\n'
#  '2. **Email Summarization Agent**:\n'
#  '   - **Function**: Once emails are retrieved, this subagent processes the '
#  'content of the emails to extract key information and highlights.\n'
#  '   - **Features**:\n'
#  '     - Natural Language Processing (NLP) for summarization.\n'
#  '     - Identify action items and deadlines.\n'
#  '     - Convert relevant email content into calendar events.\n'
#  '\n'
#  '3. **Slack Retrieval Agent**:\n'
#  '   - **Function**: This subagent connects to your Slack account using the '
#  'Slack API and retrieves messages from specified channels or direct '
#  'messages.\n'
#  '   - **Features**:\n'
#  '     - Filter by keywords or specific threads.\n'
#  '     - Fetch updates from specific users or channels.\n'
#  '\n'
#  '4. **Slack Summarization Agent**:\n'
#  '   - **Function**: Similar to the email summarization agent, this agent '
#  'processes the retrieved Slack messages to summarize key discussions and '
#  'updates.\n'
#  '   - **Features**:\n'
#  '     - Identify critical messages, announcements, or action items.\n'
#  '     - Integrate with threads to capture ongoing discussions.\n'
#  '\n'
#  '5. **Calendar Management Agent**:\n'
#  '   - **Function**: This agent interacts with your calendar (Google Calendar, '
#  'Microsoft Outlook, etc.) to create, update, or delete events based on the '
#  'information retrieved from emails and Slack.\n'
#  '   - **Features**:\n'
#  '     - Sync new events or reminders from summaries.\n'
#  '     - Adjust existing events based on updates from emails or Slack.\n'
#  '     - Keep track of conflicting events.\n'
#  '\n'
#  '6. **User Interface or Interaction Agent**:\n'
#  '   - **Function**: This could be a simple dashboard or a chatbot interface '
#  'allowing users to interact with the agents, request updates, or manually '
#  'adjust settings.\n'
#  '   - **Features**:\n'
#  '     - Provide options to configure which emails or Slack channels to '
#  'monitor.\n'
#  '     - Allow users to view a summary of updates or modify calendar events '
#  'directly.\n'
#  '\n'
#  '7. **Notification Agent**:\n'
#  '   - **Function**: Sends notifications or alerts to users for significant '
#  'updates or upcoming events.\n'
#  '   - **Features**:\n'
#  '     - Trigger notifications via preferred channels (e.g., email, Slack, '
#  'SMS).\n'
#  '     - Customize how often and in what format updates are delivered.\n'
#  '\n'
#  '8. **Data Storage Agent** (optional):\n'
#  '   - **Function**: If you want to keep a history of your summaries and '
#  'updates, this subagent can manage the storage and retrieval of past '
#  'summaries.\n'
#  '   - **Features**:\n'
#  '     - Database management to store summaries, emails, and Slack messages.\n'
#  '     - Retrieval functions to look back on specific events or updates.\n'
#  '\n'
#  '9. **Integration and Workflow Agent**:\n'
#  '   - **Function**: This component manages the integration between the '
#  'different agents, ensuring a smooth workflow from data retrieval to '
#  'summarization and calendar updates.\n'
#  '   - **Features**:\n'
#  '     - Orchestrate the sequences of operations.\n'
#  '     - Handle error management and retries if processes fail.\n'
#  '\n'
#  '### Additional Considerations:\n'
#  '- **Security and Authentication**: Ensure proper authentication methods '
#  '(OAuth, API keys) are in place for accessing email and Slack.\n'
#  '- **Customization**: Allow users to customize the keywords, filters, and '
#  'settings for summarization and notifications.\n'
#  '- **Testing and Iteration**: Start with a prototype, test it with real data, '
#  'refine the summarization techniques, and tweak the UX/UI for better '
#  'interactions.\n'
#  '\n'
#  'By modularizing each function into subagents, you can have a scalable and '
#  'maintainable system that fulfills your requirements for email, Slack, and '
#  'calendar management.')

# %%
from langchain_core.prompts import PromptTemplate

MODEL_PROMPT = PromptTemplate.from_template(
    """You are responsible for defining the relations between different different subagents.

The user query is 
<userQuery>
{userquery}
<userQuery>

THe expected functionalities 
<functions>
{functions}
<functions>

1. Identify specific nodes
2. Identify edges between them 
3. output response as A --> B for any two nodes A and B with flow from A to B"""
)
# Out:
# 'You are responsible for defining the relations between different different subagents.\n\nThe user query is \n<userQuery>\nI want to build an agent that retrieves latest updates from my email and slack, summarizes the highlights and updates my calenders for events. What are the different subagents needed?\n<userQuery>\n\nTHe expected functionalities \n<functions>\nBuilding an agent that can retrieve updates from your email and Slack, summarize highlights, and update your calendar involves several components or subagents. Below are the key subagents you might consider implementing:\n\n1. **Email Retrieval Agent**:\n   - **Function**: This subagent connects to your email account (using protocols like IMAP/SMTP) to fetch unread emails, or emails from specific folders.\n   - **Features**: \n     - Filter emails by keywords, sender, or dates.\n     - Prioritize emails based on importance (e.g., from colleagues or project tags).\n\n2. **Email Summarization Agent**:\n   - **Function**: Once emails are retrieved, this subagent processes the content of the emails to extract key information and highlights.\n   - **Features**:\n     - Natural Language Processing (NLP) for summarization.\n     - Identify action items and deadlines.\n     - Convert relevant email content into calendar events.\n\n3. **Slack Retrieval Agent**:\n   - **Function**: This subagent connects to your Slack account using the Slack API and retrieves messages from specified channels or direct messages.\n   - **Features**:\n     - Filter by keywords or specific threads.\n     - Fetch updates from specific users or channels.\n\n4. **Slack Summarization Agent**:\n   - **Function**: Similar to the email summarization agent, this agent processes the retrieved Slack messages to summarize key discussions and updates.\n   - **Features**:\n     - Identify critical messages, announcements, or action items.\n     - Integrate with threads to capture ongoing discussions.\n\n5. **Calendar Management Agent**:\n   - **Function**: This agent interacts with your calendar (Google Calendar, Microsoft Outlook, etc.) to create, update, or delete events based on the information retrieved from emails and Slack.\n   - **Features**:\n     - Sync new events or reminders from summaries.\n     - Adjust existing events based on updates from emails or Slack.\n     - Keep track of conflicting events.\n\n6. **User Interface or Interaction Agent**:\n   - **Function**: This could be a simple dashboard or a chatbot interface allowing users to interact with the agents, request updates, or manually adjust settings.\n   - **Features**:\n     - Provide options to configure which emails or Slack channels to monitor.\n     - Allow users to view a summary of updates or modify calendar events directly.\n\n7. **Notification Agent**:\n   - **Function**: Sends notifications or alerts to users for significant updates or upcoming events.\n   - **Features**:\n     - Trigger notifications via preferred channels (e.g., email, Slack, SMS).\n     - Customize how often and in what format updates are delivered.\n\n8. **Data Storage Agent** (optional):\n   - **Function**: If you want to keep a history of your summaries and updates, this subagent can manage the storage and retrieval of past summaries.\n   - **Features**:\n     - Database management to store summaries, emails, and Slack messages.\n     - Retrieval functions to look back on specific events or updates.\n\n9. **Integration and Workflow Agent**:\n   - **Function**: This component manages the integration between the different agents, ensuring a smooth workflow from data retrieval to summarization and calendar updates.\n   - **Features**:\n     - Orchestrate the sequences of operations.\n     - Handle error management and retries if processes fail.\n\n### Additional Considerations:\n- **Security and Authentication**: Ensure proper authentication methods (OAuth, API keys) are in place for accessing email and Slack.\n- **Customization**: Allow users to customize the  ...

# %%
MODEL_PROMPT
# Out:
# PromptTemplate(input_variables=['functions', 'userquery'], input_types={}, partial_variables={}, template='You are responsible for defining the relations between different different subagents.\n\nThe user query is \n<userQuery>\n{userquery}\n<userQuery>\n\nTHe expected functionalities \n<functions>\n{functions}\n<functions>\n\n1. Identify specific nodes\n2. Identify edges between them \n3. output response as A --> B for any two nodes A and B with flow from A to B')

# %%
agentdesign = llm.invoke(MODEL_PROMPT.format(userquery=userquery, functions=response.content))

# %%
agentdesign.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Based on the functionalities outlined above, we can define specific nodes (subagents) and the relationships (edges) between them. Below are the identified nodes and the directed edges illustrating the flow of information between them:
#
# ### Nodes:
#
# 1. Email Retrieval Agent
# 2. Email Summarization Agent
# 3. Slack Retrieval Agent
# 4. Slack Summarization Agent
# 5. Calendar Management Agent
# 6. User Interface or Interaction Agent
# 7. Notification Agent
# 8. Data Storage Agent (optional)
# 9. Integration and Workflow Agent
#
# ### Directed Edges:
#
# 1. Email Retrieval Agent --> Email Summarization Agent
# 2. Slack Retrieval Agent --> Slack Summarization Agent
# 3. Email Summarization Agent --> Calendar Management Agent
# 4. Slack Summarization Agent --> Calendar Management Agent
# 5. Email Summarization Agent --> User Interface or Interaction Agent
# 6. Slack Summarization Agent --> User Interface or Interaction Agent
# 7. Calendar Management Agent --> User Interface or Interaction Agent
# 8. Calendar Management Agent --> Notification Agent
# 9. Email Summarization Agent --> Data Storage Agent (optional)
# 10. Slack Summarization Agent --> Data Storage Agent (optional)
# 11. Integration and Workflow Agent --> Email Retrieval Agent
# 12. Integration and Workflow Agent --> Slack Retrieval Agent
# 13. Integration and Workflow Agent --> Email Summarization Agent
# 14. Integration and Workflow Agent --> Slack Summarization Agent
# 15. Integration and Workflow Agent --> Calendar Management Agent
# 16. Integration and Workflow Agent --> Notification Agent
# 17. Integration and Workflow Agent --> User Interface or Interaction Agent
# 18. Integration and Workflow Agent --> Data Storage Agent (optional)
#
# ### Response Output:
#
# Here’s the response formatted as requested:
#
# ```
# Email Retrieval Agent --> Email Summarization Agent
# Slack Retrieval Agent --> Slack Summarization Agent
# Email Summarization Agent --> Calendar Management Agent
# Slack Summarization Agent --> Calendar Management Agent
# Email Summarization Agent --> User Interface or Interaction Agent
# Slack Summarization Agent --> User Interface or Interaction Agent
# Calendar Management Agent --> User Interface or Interaction Agent
# Calendar Management Agent --> Notification Agent
# Email Summarization Agent --> Data Storage Agent
# Slack Summarization Agent --> Data Storage Agent
# Integration and Workflow Agent --> Email Retrieval Agent
# Integration and Workflow Agent --> Slack Retrieval Agent
# Integration and Workflow Agent --> Email Summarization Agent
# Integration and Workflow Agent --> Slack Summarization Agent
# Integration and Workflow Agent --> Calendar Management Agent
# Integration and Workflow Agent --> Notification Agent
# Integration and Workflow Agent --> User Interface or Interaction Agent
# Integration and Workflow Agent --> Data Storage Agent
# ```
#
# This framework outlines a comprehensive structure of subagents and their interconnections, showcasing how data flows through the system to achieve the desired functionalities.

# %%
### THIS IS WHERE LANGGRAPH AND LANGCHAIN COME INTO PLAY
CODEGEN_PROMPT = PromptTemplate.from_template(
    """You are responsible for generarting boiler plate python code for each agent.
       Each agent is a python function
       Model it as a graph with start node and end node, also edges and conditional edges

The subagent graph schema is 
<schema>
{schema}
<schema>
"""
)

# %%
code = llm.invoke(CODEGEN_PROMPT.format(userquery=userquery, functions = response.content, schema = agentdesign.content))

# %%
code.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Based on the provided schema of agents and their interactions, I'll generate boilerplate Python code for each of the agents. Each agent will be modeled as a function, and the connections between them will be depicted through function calls.
#
# Here is the structured boilerplate Python code for the agents:
#
# ```python
# class DataStorageAgent:
#     def store_data(self, data):
#         # Placeholder for data storage logic
#         print("Storing data:", data)
#
# class EmailRetrievalAgent:
#     def retrieve_emails(self):
#         # Placeholder for email retrieval logic
#         print("Retrieving emails...")
#         emails = ["email1", "email2"]  # Simulating retrieved emails
#         return emails
#
# class EmailSummarizationAgent:
#     def summarize_emails(self, emails):
#         # Placeholder for summarizing emails
#         print("Summarizing emails...")
#         summaries = ["Summary1", "Summary2"]  # Simulating summaries
#         return summaries
#
# class SlackRetrievalAgent:
#     def retrieve_slack_messages(self):
#         # Placeholder for Slack message retrieval logic
#         print("Retrieving Slack messages...")
#         messages = ["message1", "message2"]  # Simulating retrieved messages
#         return messages
#
# class SlackSummarizationAgent:
#     def summarize_slack_messages(self, messages):
#         # Placeholder for summarizing Slack messages
#         print("Summarizing Slack messages...")
#         summaries = ["Slack Summary1", "Slack Summary2"]  # Simulating summaries
#         return summaries
#
# class CalendarManagementAgent:
#     def manage_calendar(self, summaries):
#         # Placeholder for calendar management logic
#         print("Managing calendar with summaries:", summaries)
#
# class UserInterfaceAgent:
#     def interact_with_user(self, summaries):
#         # Placeholder for user interface interaction
#         print("Interacting with user. Showing summaries:", summaries)
#
# class NotificationAgent:
#     def send_notification(self, message):
#         # Placeholder for notification sending logic
#         print("Sending notification:", message)
#
# class IntegrationAndWorkflowAgent:
#     def run(self):
#         # Running the agents in sequence as per the directed edges
#
#         # Retrieving and processing emails
#         email_retrieval_agent = EmailRetrievalAgent()
#         emails = email_retrieval_agent.retrieve_emails()
#
#         email_summization_agent = EmailSummarizationAgent()
#         email_summaries = email_summization_agent.summarize_emails(emails)
#
#         # Retrieving and processing Slack messages
#         slack_retrieval_agent = SlackRetrievalAgent()
#         messages = slack_retrieval_agent.retrieve_slack_messages()
#
#         slack_summarization_agent = SlackSummarizationAgent()
#         slack_summaries = slack_summarization_agent.summarize_slack_messages(messages)
#
#         # Managing the calendar
#         calendar_management_agent = CalendarManagementAgent()
#         calendar_management_agent.manage_calendar(email_summaries + slack_summaries)
#
#         # Interacting with user
#         user_interface_agent = UserInterfaceAgent()
#         user_interface_agent.interact_with_user(email_summaries + slack_summaries)
#
#         # Notifications
#         notification_agent = NotificationAgent()
#         notification_agent.send_notification("You have new updates to review.")
#
#         # Optional Data Storage
#         data_storage_agent = DataStorageAgent()
#         data_storage_agent.store_data(email_summaries + slack_summaries)
#
# # Entry point of the application
# if __name__ == "__main__":
#     integration_workflow_agent = IntegrationAndWorkflowAgent()
#     integration_workflow_agent.run()
# ```
#
# ### Explanation of the Code:
#
# 1. **Agent Classes**: Each agent corresponds to a specific task, encapsulated in its own class.
#    - **DataStorageAgent**: Handles data storage.
#    - **EmailRetrievalAgent** and **SlackRetrievalAgent**: Retrieve emails and Slack messages, respectively.
#    - **EmailSummarizationAgent** and **SlackSummarizationAgent**: Summarize retrieved content.
#    - **CalendarManagementAgent**: Manages calendar updates based on summaries.
#    - **UserInterfaceAgent**: Handles user interactions.
#    - **NotificationAgent**: Sends notifications.
#
# 2. **Integration and Workflow Agent**: This is the main orchestrator that runs all other agents sequentially, linking their functionalities according to the directed edges.
#
# 3. **Main Function**: The execution starts from the `if __name__ == "__main__":` block, instantiating and running the `IntegrationAndWorkflowAgent`.
#
# This boilerplate can be further expanded with actual logic for retrieving, processing, and storing data as needed.

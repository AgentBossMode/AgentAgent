# %%
from full_formed_snippet import python_code_snippet

# %%
from openevals.code.e2b.execution import create_e2b_execution_evaluator
from dotenv import load_dotenv
from e2b_code_interpreter import Sandbox

load_dotenv()
sandbox = Sandbox()
evaluator = create_e2b_execution_evaluator(
    sandbox=sandbox,
)

# %%
eval_result = evaluator(outputs=python_code_snippet)

# %%
eval_result
# Out:
# {'key': 'execution_succeeded',
#  'score': True,
#  'comment': None,
#  'metadata': None}

# %%
files = sandbox.files.read("/home/user/sample.json")

# %%
print(files)
# Out:
# {"nodes": [{"id": "__start__", "type": "runnable", "data": {"id": ["langchain", "schema", "runnable", "RunnablePassthrough"], "name": "__start__"}}, {"id": "supervisor", "type": "runnable", "data": {"id": ["langgraph", "utils", "runnable", "RunnableCallable"], "name": "supervisor"}}, {"id": "__end__"}, {"id": "diet_agent:__start__", "type": "runnable", "data": {"id": ["langchain", "schema", "runnable", "RunnablePassthrough"], "name": "diet_agent:__start__"}}, {"id": "diet_agent:agent", "type": "runnable", "data": {"id": ["langgraph", "utils", "runnable", "RunnableCallable"], "name": "diet_agent:agent"}}, {"id": "diet_agent:tools", "type": "runnable", "data": {"id": ["langgraph", "prebuilt", "tool_node", "ToolNode"], "name": "diet_agent:tools"}}, {"id": "diet_agent:__end__"}, {"id": "exercise_agent:__start__", "type": "runnable", "data": {"id": ["langchain", "schema", "runnable", "RunnablePassthrough"], "name": "exercise_agent:__start__"}}, {"id": "exercise_agent:agent", "type": "runnable", "data": {"id": ["langgraph", "utils", "runnable", "RunnableCallable"], "name": "exercise_agent:agent"}}, {"id": "exercise_agent:tools", "type": "runnable", "data": {"id": ["langgraph", "prebuilt", "tool_node", "ToolNode"], "name": "exercise_agent:tools"}}, {"id": "exercise_agent:__end__"}, {"id": "logging_agent:__start__", "type": "runnable", "data": {"id": ["langchain", "schema", "runnable", "RunnablePassthrough"], "name": "logging_agent:__start__"}}, {"id": "logging_agent:agent", "type": "runnable", "data": {"id": ["langgraph", "utils", "runnable", "RunnableCallable"], "name": "logging_agent:agent"}}, {"id": "logging_agent:tools", "type": "runnable", "data": {"id": ["langgraph", "prebuilt", "tool_node", "ToolNode"], "name": "logging_agent:tools"}}, {"id": "logging_agent:__end__"}], "edges": [{"source": "__start__", "target": "supervisor"}, {"source": "diet_agent:__end__", "target": "supervisor", "conditional": true}, {"source": "exercise_agent:__end__", "target": "supervisor", "conditional": true}, {"source": "logging_agent:__end__", "target": "supervisor", "conditional": true}, {"source": "supervisor", "target": "diet_agent:__start__", "conditional": true}, {"source": "supervisor", "target": "exercise_agent:__start__", "conditional": true}, {"source": "supervisor", "target": "logging_agent:__start__", "conditional": true}, {"source": "supervisor", "target": "__end__", "conditional": true}, {"source": "diet_agent:__start__", "target": "diet_agent:agent"}, {"source": "diet_agent:agent", "target": "diet_agent:tools", "conditional": true}, {"source": "diet_agent:tools", "target": "diet_agent:agent"}, {"source": "diet_agent:agent", "target": "diet_agent:__end__", "conditional": true}, {"source": "exercise_agent:__start__", "target": "exercise_agent:agent"}, {"source": "exercise_agent:agent", "target": "exercise_agent:tools", "conditional": true}, {"source": "exercise_agent:tools", "target": "exercise_agent:agent"}, {"source": "exercise_agent:agent", "target": "exercise_agent:__end__", "conditional": true}, {"source": "logging_agent:__start__", "target": "logging_agent:agent"}, {"source": "logging_agent:agent", "target": "logging_agent:tools", "conditional": true}, {"source": "logging_agent:tools", "target": "logging_agent:agent"}, {"source": "logging_agent:agent", "target": "logging_agent:__end__", "conditional": true}]}

# %%
with open('sample.json', 'w') as file:
    file.write(files)

# %%
print(files)

# %% [markdown]
# # Old method which does not allow auto import

# %%
execution = sandbox.run_code(python_code_snippet) # Execute Python inside the sandbox
print(execution.logs)
# Out:
# Logs(stdout: [], stderr: [])

# %%
import json 
json_result = json.loads(eval_result["comment"])

for error in json_result:
    pprint(error)
# Out:
# {'message': '"__getitem__" method not defined on type "BaseModel"',
#  'range': {'end': {'character': 23, 'line': 102},
#            'start': {'character': 15, 'line': 102}},
#  'rule': 'reportIndexIssue',
#  'severity': 'error'}
# {'message': 'Type "(state: State) -> Command[Literal[\'diet_agent\', '
#             '\'exercise_agent\', \'logging_agent\', \'__end__\']]" is not '
#             'assignable to return type "str"\n'
#             '\xa0\xa0"function" is not assignable to "str"',
#  'range': {'end': {'character': 26, 'line': 108},
#            'start': {'character': 11, 'line': 108}},
#  'rule': 'reportReturnType',
#  'severity': 'error'}
# {'message': 'Argument of type "str" cannot be assigned to parameter "action" '
#             'of type "RunnableLike[Unknown, Unknown]" in function "add_node"\n'
#             '\xa0\xa0Type "str" is not assignable to type '
#             '"RunnableLike[Unknown, Unknown]"\n'
#             '\xa0\xa0\xa0\xa0"str" is not assignable to "Runnable[Unknown, '
#             'Unknown]"\n'
#             '\xa0\xa0\xa0\xa0Type "str" is not assignable to type "(Unknown) '
#             '-> Unknown"\n'
#             '\xa0\xa0\xa0\xa0Type "str" is not assignable to type "(Unknown) '
#             '-> Awaitable[Unknown]"\n'
#             '\xa0\xa0\xa0\xa0Type "str" is not assignable to type '
#             '"(Iterator[Unknown]) -> Iterator[Unknown]"\n'
#             '\xa0\xa0\xa0\xa0Type "str" is not assignable to type '
#             '"(AsyncIterator[Unknown]) -> AsyncIterator[Unknown]"\n'
#             '\xa0\xa0\xa0\xa0"str" is incompatible with protocol '
#             '"_RunnableCallableSync[Unknown, Unknown]"\n'
#             '\xa0\xa0\xa0\xa0\xa0\xa0"__call__" is not present\n'
#             '  ...',
#  'range': {'end': {'character': 60, 'line': 119},
#            'start': {'character': 39, 'line': 119}},
#  'rule': 'reportArgumentType',
#  'severity': 'error'}
